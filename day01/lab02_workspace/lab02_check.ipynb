# %% [markdown]
# ## 실습 2: 작업실 점검
# - 목표: 환경이 제대로 준비됐는지 확인

# %% [markdown]
# ### 용어 풀이 - 오늘 쓴 도구 이름
#
# | 말 | 뜻 |
# |---|---|
# | VS Code | 파일, 코드, AI 대화를 한 화면에서 다루는 작업대 |
# | 확장 | VS Code에 기능을 끼워 넣는 부품. Claude Code도 그중 하나 |
# | 라이브러리 | 남이 미리 만들어둔 도구 묶음 (표 다루기, 그래프 그리기 등) |
# | PATH | 컴퓨터가 프로그램을 찾아가는 길 목록 |
# | 노트북 (.ipynb) | 코드 칸과 글 칸을 섞어 쓰는 파일 |
# | 커널 | 노트북의 칸을 실제로 실행해주는 엔진 |

# %%
# 화면에 글자를 찍어보는 가장 간단한 확인
print("작업실 준비 완료")
# Out:
# 작업실 준비 완료

# %% [markdown]
# ---
# ## 직접 해보기 (도전) - 책상에 이름표 붙이기
#
# - 상황: 이 자리를 처음 보는 사람이 "무슨 프로젝트지?"부터 묻는다
# - 할 일: 폴더 맨 위에 안내문 파일을 만든다
# - 결과물: README.md 파일 1개 (제목, 한 줄 설명, 폴더 구조 설명)
